# %% [markdown]
# # Bandwith-Evaluation
#
# ## List of testtraces:
# - 07-05-2024-roofmounted-inside
# - 04-06-2024-roofmounted-inside
# - 05-06-2024-mounted-outside

# %% [markdown]
# ### 1. Install dependencies

# %%
# %%capture
# !pip install ipykernel;
# !pip install matplotlib;
# !pip install seaborn;
# !pip install folium;
import pandas as pd;
import geopandas as gpd;
import folium;
import os;
import seaborn as sns

# %% [markdown]
# ### 2. Load testtraces

# %%
testtraces_inside = dict()
testtraces_outside = dict()

# mounted inside
for dir in os.listdir('../results'):
    if "inside" in dir:
        testtraces_inside[dir] = []
        try:
            for file in os.listdir(os.path.join('../results', dir)):
                if "pcap" not in file:
                    file_path = os.path.join('../results', dir, file)
                    df = pd.read_csv(file_path)
                    testtraces_inside[dir].append(df)
        except Exception as e:
            print(f"Failed to read {file_path}: {e}")

# mounted outside
for dir in os.listdir('../results'):
    if "outside" in dir:
        testtraces_outside[dir] = []
        try:
            for file in os.listdir(os.path.join('../results', dir)):
                if "pcap" not in file:
                    file_path = os.path.join('../results', dir, file)
                    df = pd.read_csv(file_path)
                    testtraces_outside[dir].append(df)
        except Exception as e:
            print(f"Failed to read {file_path}: {e}")

# %% [markdown]
# ### 3. Plotting of bandiwth-results depending on distance:

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

plt.figure(figsize=(8, 6))

colors = ['blue', 'green', 'red', 'orange', 'purple', 'yellow']  # Customize as needed
markers = ['.', ',', 'v', '8', 's', 'p']

for testname, list_of_dfs in testtraces_inside.items():
    for i, df in enumerate(list_of_dfs):
        # Choose a color for each DataFrame
        color = colors[i % len(colors)]
        marker = markers[i % len(markers)]

        plt.scatter(
            df['Distance'], 
            df['Bitrate'],
            marker=marker, 
            color=color, 
            alpha=0.5, 
            label=f'{testname}'
        )
        
    plt.title(f'Bitrate vs. Distance')
    plt.xlabel('Distance [m]')
    plt.ylabel('Bitrate [MBit/s]')

plt.legend()
plt.show()

# outside
plt.figure(figsize=(8, 6))

colors = ['blue', 'green', 'red', 'orange', 'purple', 'yellow']  # Customize as needed
markers = ['.', ',', 'v', '8', 's', 'p']

for testname, list_of_dfs in testtraces_outside.items():
    for i, df in enumerate(list_of_dfs):
        # Choose a color for each DataFrame
        color = colors[i % len(colors)]
        marker = markers[i % len(markers)]

        plt.scatter(
            df['Distance'], 
            df['Bitrate'],
            marker=marker, 
            color=color, 
            alpha=0.5, 
            label=f'{testname}'
        )
        
    plt.title(f'Bitrate vs. Distance')
    plt.xlabel('Distance [m]')
    plt.ylabel('Bitrate [MBit/s]')

plt.legend()
plt.show()

# %% [markdown]
# ### 4. Plotting of bandiwth-results on geo-map **_roofmounted-inside_**:
#
# 1. Set center of basemap to georeference-point
# 2. Print colored datapoints from df according to bandwith

# %%
from config import REF_POINT
from folium import CircleMarker
from branca.colormap import linear

# 0 SCALE_VALUES
MIN_SCALE_BITRATE = 0
MAX_SCALE_BITRATE = 100

# 1. init map at center-georef-point
map_osm = folium.Map(
    location=[REF_POINT[0], REF_POINT[1]], 
    zoom_start=19,
    )


# 2. print measurement-points 
color_scale = linear.viridis.scale(MIN_SCALE_BITRATE, MAX_SCALE_BITRATE)

for testname, list_of_dfs in testtraces_inside.items():
    for i, df in enumerate(list_of_dfs):
        print(testname)
        for df in list_of_dfs:
            for _, row in df.iterrows():
                folium.CircleMarker(
                    location=[row['Latitude'], row['Longitude']],
                    radius=5,  # Adjust the size of the marker as needed
                    color=color_scale(row['Bitrate']),
                    fill=True,
                    fill_opacity=0.7,
                ).add_to(map_osm)

# Add the color scale legend to the map
color_scale.caption = 'Bitrate [MBit/s]'
map_osm.add_child(color_scale)

map_osm
# Out:
# bandwithtest_06052024_roofmounted-inside
# bandwithtest_06052024_roofmounted-inside
# bandwithtest_06052024_roofmounted-inside
# bandwithtest_06052024_roofmounted-inside
# bandwithtest_06052024_roofmounted-inside
# bandwithtest_04062024_roofmounted-inside
# bandwithtest_04062024_roofmounted-inside
# bandwithtest_04062024_roofmounted-inside
# bandwithtest_04062024_roofmounted-inside
# bandwithtest_04062024_roofmounted-inside
# bandwithtest_04062024_roofmounted-inside
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c9fe1fc669b4c56e718d6ec29d1d2d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c9fe1fc669b4c56e718d6ec29d1d2d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c9fe1fc669b4c56e718d6ec29d1d2d7 = L.map(
#                 &quot;map_2c9fe1fc669b4c56e718d6ec29d1d2d7&quot;,
#                 {
#                     center: [52.315827, 10.561689],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 19,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0839e602217f95bba38007a43110f22 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e0839e602217f95bba38007a43110f22.addTo(map_2c9fe1fc669b4c56e718d6ec29d1d2d7);
#
#
#             var circle_marker_f2eddae655ab39bc786b0a4b92ae6d7c = L.circleMarker(
#                 [52.314884539, 10.561514155],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#45075aff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#45075aff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2c9fe1fc669b4c56e718d6ec29d1d2d7);
#
#
#             var circle_marker_719988464ad6c9894deef66a1f2126b7 = L.circleMarker(
#                 [52.314884539, 10.561514155],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#482677ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#482677ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2c9fe1fc669b4c56e718d6ec29d1d2d7);
#
#
#             var circle_marker_d55d818c60a3bede0cafc52ab76fcf94 = L.circleMarker(
#                 [52.314884539, 10.561514155],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#482476ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#482476ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2c9fe1fc669b4c56e718d6ec29d1d2d7);
#
#
#             var circle_marker_88cc9f190a5784112a38ebe4da543f2d = L.circleMarker(
#                 [52.31538451, 10.56160767],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#45085bff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#45085bff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2c9fe1fc669b4c56e718d6ec29d1d2d7);
#
#
#             var circle_marker_fb732108f11ea83dcb7229ca6571d2d6 = L.circleMarker(
#                 [52.315439821, 10.561614702],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#45085bff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#45085bff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2c9fe1fc669b4c56e718d6ec29d1d2d7);
#
#
#             var circle_marker_68bb6a2c1740de4a6e218042701174f3 = L.circleMarker(
#                 [52.315491819, 10.56162129],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#450458ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#450458ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2c9fe1fc669b4c5

# %% [markdown]
# ### 4. Plotting of bandiwth-results on geo-map **_roofmounted-outside_**:
#
# 1. Set center of basemap to georeference-point
# 2. Print colored datapoints from df according to bandwith

# %%
for testname, list_of_dfs in testtraces_outside.items():
    for i, df in enumerate(list_of_dfs):
        print(testname)
        for df in list_of_dfs:
            for _, row in df.iterrows():
                folium.CircleMarker(
                    location=[row['Latitude'], row['Longitude']],
                    radius=5,  # Adjust the size of the marker as needed
                    color=color_scale(row['Bitrate']),
                    fill=True,
                    fill_opacity=0.7,
                ).add_to(map_osm)

# Add the color scale legend to the map
color_scale.caption = 'Bitrate [MBit/s]'
map_osm.add_child(color_scale)

map_osm
# Out:
# bandwithtest_05062024_outside
# bandwithtest_05062024_outside
# bandwithtest_05062024_outside
# bandwithtest_05062024_outside
# bandwithtest_05062024_outside
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c9fe1fc669b4c56e718d6ec29d1d2d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c9fe1fc669b4c56e718d6ec29d1d2d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c9fe1fc669b4c56e718d6ec29d1d2d7 = L.map(
#                 &quot;map_2c9fe1fc669b4c56e718d6ec29d1d2d7&quot;,
#                 {
#                     center: [52.315827, 10.561689],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 19,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0839e602217f95bba38007a43110f22 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e0839e602217f95bba38007a43110f22.addTo(map_2c9fe1fc669b4c56e718d6ec29d1d2d7);
#
#
#             var circle_marker_f2eddae655ab39bc786b0a4b92ae6d7c = L.circleMarker(
#                 [52.314884539, 10.561514155],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#45075aff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#45075aff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2c9fe1fc669b4c56e718d6ec29d1d2d7);
#
#
#             var circle_marker_719988464ad6c9894deef66a1f2126b7 = L.circleMarker(
#                 [52.314884539, 10.561514155],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#482677ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#482677ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2c9fe1fc669b4c56e718d6ec29d1d2d7);
#
#
#             var circle_marker_d55d818c60a3bede0cafc52ab76fcf94 = L.circleMarker(
#                 [52.314884539, 10.561514155],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#482476ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#482476ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2c9fe1fc669b4c56e718d6ec29d1d2d7);
#
#
#             var circle_marker_88cc9f190a5784112a38ebe4da543f2d = L.circleMarker(
#                 [52.31538451, 10.56160767],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#45085bff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#45085bff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2c9fe1fc669b4c56e718d6ec29d1d2d7);
#
#
#             var circle_marker_fb732108f11ea83dcb7229ca6571d2d6 = L.circleMarker(
#                 [52.315439821, 10.561614702],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#45085bff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#45085bff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2c9fe1fc669b4c56e718d6ec29d1d2d7);
#
#
#             var circle_marker_68bb6a2c1740de4a6e218042701174f3 = L.circleMarker(
#                 [52.315491819, 10.56162129],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#450458ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#450458ff&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2c9fe1fc669b4c5
